# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n = pd.read_csv(r"C:\Users\Dell\Downloads\netflix_titles.csv")

# %%
n
# Out:
#      show_id     type                  title         director
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Task = 1

# %%
n.duplicated().any()
# Out:
# False

# %% [markdown]
# # Task = 2

# %%
n.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(n.isnull())
# Out:
# <Axes: >

# %%
#  white shows null values

# %%
# Q1
a = n.set_index("title")
a
# Out:
#                       show_id     type         director
# title
# Dick Johnson Is Dead       s1    Movie  Kirsten Johnson  \
# Blood & Water              s2  TV Show              NaN
# Ganglands                  s3  TV Show  Julien Leclercq
# Jailbirds New Orleans      s4  TV Show              NaN
# Kota Factory               s5  TV Show              NaN
# ...                       ...      ...              ...
# Zodiac                  s8803    Movie    David Fincher
# Zombie Dumb             s8804  TV Show              NaN
# Zombieland              s8805    Movie  Ruben Fleischer
# Zoom                    s8806    Movie     Peter Hewitt
# Zubaan                  s8807    Movie      Mozez Singh
#
#                                                                     cast
# title
# Dick Johnson Is Dead                                                 NaN  \
# Blood & Water          Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
a.loc["House of Cards"]
# Out:
# show_id                                                     s1060
# type                                                      TV Show
# director                                                      NaN
# cast            Kevin Spacey, Robin Wright, Kate Mara, Corey S...
# country                                             United States
# date_added                                         April 14, 2021
# release_year                                                 2018
# rating                                                      TV-MA
# duration                                                6 Seasons
# listed_in                                 TV Dramas, TV Thrillers
# description     A ruthless politician will stop at nothing to ...
# Name: House of Cards, dtype: object

# %%
# director = nan
# show id = s1060

# %% [markdown]
# # Q. 2) In which year the highest number of TV Shows & Movies were released? Show with Bar Graph

# %%
high_year=pd.DataFrame(n.groupby('type')[['release_year']].value_counts())

# %%
high_year.sort_values(by='count',ascending=False)
# Out:
#                       count
# type    release_year
# Movie   2017            767
#         2018            767
#         2016            658
#         2019            633
#         2020            517
# ...                     ...
#         1966              1
#         1946              1
#         1947              1
#         1963              1
# TV Show 1989              1
#
# [119 rows x 1 columns]

# %%
high_year.reset_index(inplace=True)

# %%
high_year
# Out:
#         type  release_year  count
# 0      Movie          2017    767
# 1      Movie          2018    767
# 2      Movie          2016    658
# 3      Movie          2019    633
# 4      Movie          2020    517
# ..       ...           ...    ...
# 114  TV Show          1977      1
# 115  TV Show          1979      1
# 116  TV Show          1981      1
# 117  TV Show          1985      1
# 118  TV Show          1989      1
#
# [119 rows x 3 columns]

# %%
df_movie=high_year[high_year['type']=='Movie'].sort_values(by='count',ascending=False).head(10)
df_show=high_year[high_year['type']=='TV Show'].sort_values(by='count',ascending=False).head(10)

# %%
sns.barplot(x='release_year',y='count',data=df_movie)
plt.title('Movie Per year')
plt.show()

# %%
sns.barplot(x='release_year',y='count',data=df_show)
plt.title('TV Show per year')
plt.show()

# %% [markdown]
# # Q3 =  How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
n['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
sns.barplot(x = n['type'].value_counts().index, y = n['type'].value_counts())
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# # Q4 = Show all the Movies that were released in the year 2000

# %%
n[(n['release_year']==2000)&(n['type']=='Movie')]
# Out:
#      show_id   type                                              title
# 180     s181  Movie                 The Nutty Professor II: The Klumps  \
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# # Q. 5) Show only the Titles of all TV Shows that were released in India only

# %%
b = n[(n['country']== 'India')&(n['type']=='TV Show')]
b
# Out:
#      show_id     type                               title director
# 4         s5  TV Show                        Kota Factory      NaN  \
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India  \
# ...

# %%
b.title
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# # Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix?

# %%
n['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# # Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom"

# %%
k = n[(n['country']== 'United Kingdom')|(n['type']=='Movie') & (n['listed_in']== 'Comedies')]
k
# Out:
#      show_id     type                                   title
# 8         s9  TV Show           The Great British Baking Show  \
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  \
# ...

# %% [markdown]
# # Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
n[(n['cast']== 'Tom Cruise')].count()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# #  Q. 12) How can we sort the dataset by Year ?

# %%
n.sort_values(by = 'release_year')
# Out:
#      show_id     type                                          title
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*  \
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director
# 4250                          NaN  \
# 7790                  Frank Capra
# ...

# %% [markdown]
# # Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
z = n[(n.type == 'Movie')&(n.rating == 'TV-14')&(n.country == 'Canada')]
z
# Out:
#      show_id   type                                        title
# 157     s158  Movie                                     Level 16  \
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director
# ...

# %%
z.value_counts().sum()
# Out:
# 10

# %% [markdown]
# # Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
n[(n.type == 'TV shows')&(n.release_year > 2018)&(n.rating == 'R')].value_counts().sum()
# Out:
# 0

# %% [markdown]
# # Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
x = n.set_index('duration')
x
# Out:
#           show_id     type                  title         director
# duration
# 90 min         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 2 Seasons      s2  TV Show          Blood & Water              NaN
# 1 Season       s3  TV Show              Ganglands  Julien Leclercq
# 1 Season       s4  TV Show  Jailbirds New Orleans              NaN
# 2 Seasons      s5  TV Show           Kota Factory              NaN
# ...           ...      ...                    ...              ...
# 158 min     s8803    Movie                 Zodiac    David Fincher
# 2 Seasons   s8804  TV Show            Zombie Dumb              NaN
# 88 min      s8805    Movie             Zombieland  Ruben Fleischer
# 88 min      s8806    Movie                   Zoom     Peter Hewitt
# 111 min     s8807    Movie                 Zubaan      Mozez Singh
#
#                                                         cast        country
# duration
# ...

# %% [markdown]
# # Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category
# #         is 'TV Show' & Type is 'Kids' TV'.** Task. 1) Is there any Duplicate Record in this dataset
# #         ? If yes, then remove the duplicate records."Country is United Kingdom"

# %%
y= n[(n.type == 'Movie')& (n.listed_in == 'Dramas')|
      (n.type == 'TV Shows')& (n.listed_in == 'Kids')]
y
# Out:
#      show_id   type                title             director
# 112     s113  Movie                Worth       Sara Colangelo  \
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...  \
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %%
y.duplicated().any()
# Out:
# False

# %% [markdown]
# # Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
n[n['type'] == 'TV Show'].country.value_counts()
# Out:
# country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %% [markdown]
# # Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
n.sort_values(by='duration',ascending=False).head(1)
# Out:
#      show_id   type                                  title      director
# 1329   s1330  Movie  The Misadventures of Hedi and Cokeman  Julien Royal  \
#
#                                                    cast country
# 1329  Hedi Bouchenafa, Nassim Lyes, Fred Testot, Jul...  France  \
#
#              date_added  release_year rating duration
# 1329  February 10, 2021          2021  TV-MA   99 min  \
#
#                            listed_in
# 1329  Comedies, International Movies  \
#
#                                             description
# 1329  In Paris, two dysfunctional dealers use family...
